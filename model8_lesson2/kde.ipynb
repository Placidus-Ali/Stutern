# %% [markdown]
# Q1: Highlight the key differences between KDE plots, box plots and violin plots

# %% [markdown]
# A violin plot is more informative than a box plot. While a box plot only shows summary statistics such as mean/median and interquartile ranges, the violin plot shows the full distribution of the data. The difference is particularly useful when the data distribution is multimodal. In this case a violin plot shows the presence of different peaks, their position and relative amplitude. While a KDE plot gives us the sense of a univariate curve(only one variable).

# %% [markdown]
# Importing the necessary libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib
from matplotlib import pyplot as plt

# %% [markdown]
# Loading my tips dataset

# %%
tip = sns.load_dataset('tips')
tip.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# Q2: Generate a KDE plot for the size feature of the tips dataset

# %%
sns.kdeplot(tip['size'], shade=True, color='red')
plt.xlabel('Size')
plt.show()

# %% [markdown]
# Explain the kde plot above

# %% [markdown]
# Q3: Generate the distribution of total bill by gender for the tips dataset using the boxplots

# %%
sns.boxplot(data=tip, x='sex', y='total_bill', fliersize=5, linewidth=2)
plt.title('Distribution of Total Bill by Gender')
plt.xlabel('Gender')
plt.ylabel('Total Bill')
plt.show()

# %% [markdown]
# Explain the boxplot above

# %% [markdown]
# Q4: Generate the distribution of tips by days using boxplots

# %%
sns.boxplot(data=tip, x='day', y='tip', fliersize=5, linewidth=2)
plt.title('Distribution of Tips by Day')
plt.xlabel('Day')
plt.ylabel('Tips')
plt.show()

# %% [markdown]
# Explain the plot above

# %% [markdown]
# Q5: Using boxplots generate the distribution of total bill by days considering smoker status of the customer

# %%
sns.boxplot(data=tip, x='day', y='total_bill', hue='smoker', linewidth=2)
plt.title('Distribution of Tips by Day')
plt.xlabel('Day')
plt.ylabel('Tips')
plt.show()

# %% [markdown]
# Explain the plot above

# %% [markdown]
# Q6: Using violin plots generate the distribution of total bill by time given the genders

# %%
plt.figure(figsize=(10,8))
sns.violinplot(data=tip, y=tip['total_bill'], x=tip['time'], orient='v', hue='sex')
plt.title('Distribution of Tips by Day')
plt.xlabel('Time')
plt.ylabel('Total Bill')
plt.show()

# %% [markdown]
# Explain the plot above

# %% [markdown]
# Q7: Using violin plots generate the distribution of tips by days also considering time

# %%
plt.figure(figsize=(10,8))
sns.violinplot(data=tip, y=tip['day'], x=tip['tip'], orient='h', hue='time', palette="Set2")
plt.title('Distribution of Tips by Days also considering time')
plt.xlabel('Day')
plt.ylabel('Tips')
plt.show()

# %% [markdown]
# Explain the plot above

# %% [markdown]
# Q8: Plot and customize a correlations heatmap for the tips dataset.

# %%
corr = tip.corr()
corr
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
plt.figure(figsize=(5,4))
corr= tip.corr()

# Getting the Upper Triangle of the correlation matrix
matrix = np.triu(corr)

# using the upper triangle matrix as mask 
sns.heatmap(corr, annot=True, mask=matrix, vmin=0, vmax=1,linewidths=0.5)
plt.title('Correlations Heatmap of the Tips Dataset')
plt.show()

# %% [markdown]
# Eplain the plot above
